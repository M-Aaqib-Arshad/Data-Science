# %%
# libraries 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ship = sns.load_dataset("titanic")

# %%
ship.to_csv('titanic.csv')

# %%
ship.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
ship.shape
# Out:
# (891, 15)

# %%
ship.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Uniqe value
ship.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
# columns name
ship.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
ship['survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
ship.nunique(axis=1).head()
# Out:
# 0    11
# 1    10
# 2    11
# 3    11
# 4    11
# dtype: int64

# %%
ship["sex"].drop_duplicates()
# Out:
# 0      male
# 1    female
# Name: sex, dtype: object

# %%
ship['sex' and 'survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Finding and Cleaning the values

# %%
ship.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# del the deck column
newShip = ship.drop(['deck'],axis=1)

# %%
# Remove the missing values
newShip = newShip.dropna()
newShip.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
# Counts the value 
newShip["sex"].value_counts()
# Out:
# sex
# male      453
# female    259
# Name: count, dtype: int64

# %%
ship.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
newShip.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %%
newShip.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
sns.boxplot(x='sex',y='age',data=newShip)
# To check outliers
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# To check outliers 
sns.displot(newShip['age'])
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# removing Outliers 
newShip = newShip[newShip['age']<65]
newShip['age'].max()
# Out:
# 64.0

# %%
sns.boxplot(x='sex',y='age',data=newShip)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.distplot(newShip['age'])
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_9688\3395487653.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(newShip['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
# remove the child to make normalize the bel curve
newShip = newShip[newShip['age']>10]

# %%
sns.distplot(newShip['age'])
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_9688\3395487653.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(newShip['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
newShip.boxplot()
# Out:
# <Axes: >

# %%
newShip = newShip[newShip['fare']<300]

# %%
newShip.boxplot()
# Out:
# <Axes: >

# %%
sns.distplot(newShip['fare'])
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_9688\4277074506.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(newShip['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.displot(newShip['fare_Log'])
plt.show()
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
NormShipData = newShip[newShip['fare']<200]
NormShipData['fare_Log'] = np.log(NormShipData['fare'])
NormShipData.head(20)
# Out:
# c:\Python311\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\muham\AppData\Local\Temp\ipykernel_9688\4188543089.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NormShipData['fare_Log'] = np.log(NormShipData['fare'])
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# ...

# %%
sns.boxplot(x='sex',y='fare',data=newShip)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.catplot(x='sex',y='fare',data=newShip,kind='box')
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='sex',y='fare_Log',data=NormShipData,kind='box')
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
newShip.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
sns.barplot(x="sex",y="survived",data=newShip,hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
pd.value_counts(newShip['survived']).plot.bar()
# Out:
# <Axes: xlabel='survived'>

# %%
# ks = newShip.groupby(['sex','survived'])
# ks.mean()
newShip.groupby(['sex', 'survived','pclass'] )['survived'].count()
# Out:
# sex     survived  pclass
# female  0         1           2
#                   2           6
#                   3          44
#         1         1          79
#                   2          60
#                   3          36
# male    0         1          56
#                   2          82
#                   3         198
#         1         1          35
#                   2           6
#                   3          30
# Name: survived, dtype: int64

# %%
newShip.groupby(['sex', 'survived'] )['survived'].count()
# Out:
# sex     survived
# female  0            52
#         1           175
# male    0           336
#         1            71
# Name: survived, dtype: int64

# %%
newShip.groupby(['sex', 'survived'] )['survived'].count().unstack(1)
# Out:
# survived    0    1
# sex
# female     52  175
# male      336   71

# %%
newShip.groupby(['sex', 'survived'] )['survived'].count().unstack('sex')
# Out:
# sex       female  male
# survived
# 0             52   336
# 1            175    71

# %%
newShip.groupby(['sex', 'survived'] )['survived'].count().plot.bar(figsize=(8, 6))
# Out:
# <Axes: xlabel='sex,survived'>

# %%
group = newShip.groupby(['pclass', 'survived','sex'])
pclass_survived = group.size().unstack()
 
# Heatmap - Color encoded 2D representation of data.
sns.heatmap(pclass_survived, annot = True, fmt ="d")
# Out:
# <Axes: xlabel='sex', ylabel='pclass-survived'>

# %%
newShip.groupby(['sex','class']).count()
# Out:
#                survived  pclass  age  sibsp  parch  fare  embarked  who  \
# sex    class
# female First         81      81   81     81     81    81        81   81
#        Second        66      66   66     66     66    66        66   66
#        Third         80      80   80     80     80    80        80   80
# male   First         91      91   91     91     91    91        91   91
#        Second        88      88   88     88     88    88        88   88
#        Third        228     228  228    228    228   228       228  228
#
#                adult_male  embark_town  alive  alone
# sex    class
# female First           81           81     81     81
#        Second          66           66     66     66
#        Third           80           80     80     80
# male   First           91           91     91     91
#        Second          88           88     88     88
#        Third          228          228    228    228

# %%
newShip.groupby(['sex','class','who','survived'])['survived'].count()
# Out:
# sex     class   who    survived
# female  First   child  0             0
#                        1             2
#                 man    0             0
#                        1             0
#                 woman  0             2
#                        1            77
#         Second  child  0             0
#                        1             2
#                 man    0             0
#                        1             0
#                 woman  0             6
#                        1            58
#         Third   child  0             3
#                        1             5
#                 man    0             0
#                        1             0
#                 woman  0            41
#                        1            31
# male    First   child  0             0
#                        1             1
#                 man    0            56
#                        1            34
#                 woman  0             0
# ...

# %%
titanic = sns.load_dataset('titanic')
# titanic.groupby('sex').mean()
# titanic.groupby('sex').sum().reset_index().head()
Younger = titanic.loc[titanic['age']<16]

# %%
for i in [titanic]:
    # Age - ordinal values
  
    i.loc[i['age'] <= 16, 'age'] = 0
    i.loc[(i['age'] > 16) & (i['age'] <= 32), 'age'] = 1
    i.loc[(i['age'] > 32) & (i['age'] <= 48), 'age'] = 2
    i.loc[(i['age'] > 48) & (i['age'] <= 64), 'age'] = 3
    i.loc[i['age'] > 64, 'age'] = 4

ax = sns.countplot(x=titanic.age)
plt.title('newShip.age')
for p in ax.patches:
   ax.annotate("%.0f" % p.get_height(),(p.get_x()+p.get_width()/2.,p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
titanic['age'].mean()
# Out:
# 29.69911764705882

# %%
titanic.groupby(['age','pclass'])['pclass'].mean()
# Out:
# age    pclass
# 0.42   3         3.0
# 0.67   2         2.0
# 0.75   3         3.0
# 0.83   2         2.0
# 0.92   1         1.0
#                 ...
# 70.00  2         2.0
# 70.50  3         3.0
# 71.00  1         1.0
# 74.00  3         3.0
# 80.00  1         1.0
# Name: pclass, Length: 182, dtype: float64

# %%
sns.heatmap(titanic.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[289], line 1
# ----> 1 sns.heatmap(titanic.corr())
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
sns.relplot(x='age',y='fare',hue='sex',data=newShip)
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='sex',y='fare',hue='sex',data=newShip,kind="bar")
sns.catplot(x='sex',y='age',hue='sex',data=newShip,kind="box")
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
