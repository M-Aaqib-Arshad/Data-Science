# %% [markdown]
# # Data Wrangling
# * Handle missing values
# * Data Formating
# * Data Normalization
#    * Centeralizing
#    * Scalling
# * Data Binning
# * Making Dummies of catergorical  data
#    * catergorical ---> Numerical

# %%
# libraries 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ship = sns.load_dataset('titanic')
ship.isnull().sum()
Sp2 = ship

# %%
ship.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
ship.shape
ship = ship.dropna()
ship.shape
ship.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
# use .dropna method

ship.dropna(subset=['deck'], axis=0, inplace=True)
ship.dropna(subset=['age'], axis=0, inplace=True)
ship.dropna(subset=['embark_town'], axis=0, inplace=True)
ship.dropna(subset=['embarked'], axis=0, inplace=True)
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\590141111.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ship.dropna(subset=['deck'], axis=0, inplace=True)
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\590141111.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ship.dropna(subset=['age'], axis=0, inplace=True)
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\590141111.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
ship.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
ship.shape
# Out:
# (182, 15)

# %%
mean = Sp2["age"].mean()
mean
# Out:
# 29.69911764705882

# %%
Sp2["age"] = Sp2["age"].replace(np.nan, mean)
Sp2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# to view data types of columns
ship.dtypes
# to change data type of any column
ship['survived'] = ship["survived"].astype("float64")
ship['age'] = ship["age"].astype("int64")
ship.dtypes
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\2321197162.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ship['survived'] = ship["survived"].astype("float64")
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\2321197162.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ship['age'] = ship["age"].astype("int64")
# survived        float64
# pclass            int64
# sex              object
# age               int64
# sibsp             int64
# parch             int64
# ...

# %%
Sp2['age'] = Sp2['age'].astype("int64")
Sp3 = Sp2.dropna()
Sp3
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 1           1       1  female   38      1      0  71.2833        C  First
# 3           1       1  female   35      1      0  53.1000        S  First
# 6           0       1    male   54      0      0  51.8625        S  First
# 10          1       3  female    4      1      1  16.7000        S  Third
# 11          1       1  female   58      0      0  26.5500        S  First
# ..        ...     ...     ...  ...    ...    ...      ...      ...    ...
# 871         1       1  female   47      1      1  52.5542        S  First
# 872         0       1    male   33      0      0   5.0000        S  First
# 879         1       1  female   56      0      1  83.1583        C  First
# 887         1       1  female   19      0      0  30.0000        S  First
# 889         1       1    male   26      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
Sp3["age"] = Sp3["age"] * 365

Sp3["age"].head()
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\3779562337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sp3["age"] = Sp3["age"] * 365
# 1     13870
# 3     12775
# 6     19710
# 10     1460
# 11    21170
# Name: age, dtype: int64

# %%
# always rename the afterwards
Sp3.rename(columns={"age":"age in days"},inplace=True)
Sp3
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\925772997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sp3.rename(columns={"age":"age in days"},inplace=True)
#      survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1           1       1  female        13870      1      0  71.2833        C
# 3           1       1  female        12775      1      0  53.1000        S
# 6           0       1    male        19710      0      0  51.8625        S
# 10          1       3  female         1460      1      1  16.7000        S
# 11          1       1  female        21170      0      0  26.5500        S
# ..        ...     ...     ...          ...    ...    ...      ...      ...
# 871         1       1  female        17155      1      1  52.5542        S
# ...

# %% [markdown]
# # Data Normalization
# * Uniform hte data
# * they have same impack
# * A fish in jar or A fish in sea
# * Also for computational reasons

# %% [markdown]
# # Method of Normalization
# 1. Simple Feature scalling
#    * x(new) = x(old)/x(max)
# 2. Min - Max method
# 3. Z-score (standard score) -3 -to- +3
# 4. Log transformation

# %%
Sp4 = Sp3[["age in days","fare"]]
Sp5 = Sp3[["age in days","fare"]]
Sp6 = Sp3[["age in days","fare"]]
Sp7 = Sp3[["age in days","fare"]]
Sp4.head()
# Out:
#     age in days     fare
# 1         13870  71.2833
# 3         12775  53.1000
# 6         19710  51.8625
# 10         1460  16.7000
# 11        21170  26.5500

# %%
# Simple feature scalling
Sp4['fare'] = Sp4['fare']/ Sp4['fare'].max()
Sp4['age in days'] = Sp4['age in days']/ Sp4['age in days'].max()
Sp4.head()
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\3595910509.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sp4['fare'] = Sp4['fare']/ Sp4['fare'].max()
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\3595910509.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sp4['age in days'] = Sp4['age in days']/ Sp4['age in days'].max()
#     age in days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# ...

# %%
# Min - Max  method
Sp5.head()
Sp5['fare'] = (Sp5['fare']-Sp5['fare'].min())/(Sp5['fare'].max()-Sp5['fare'].min())
Sp5.head()
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\1938308749.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sp5['fare'] = (Sp5['fare']-Sp5['fare'].min())/(Sp5['fare'].max()-Sp5['fare'].min())
#     age in days      fare
# 1         13870  0.139136
# 3         12775  0.103644
# 6         19710  0.101229
# 10         1460  0.032596
# 11        21170  0.051822

# %%
# Z score
Sp6['fare'] = (Sp6['fare']-Sp6['fare'].mean())/Sp6['fare'].std()
Sp6['fare'].head()
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\271145284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sp6['fare'] = (Sp6['fare']-Sp6['fare'].mean())/Sp6['fare'].std()
# 1    -0.067057
# 3    -0.309853
# 6    -0.326377
# 10   -0.795891
# 11   -0.664367
# Name: fare, dtype: float64

# %%
# log method
Sp7['fare'] = np.log(Sp7['fare'])
Sp7.head()
# Out:
# c:\Python311\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\muham\AppData\Local\Temp\ipykernel_10764\2147545700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sp7['fare'] = np.log(Sp7['fare'])
#     age in days      fare
# 1         13870  1.450832
# 3         12775  1.379314
# 6         19710  1.373360
# 10         1460  1.035107
# 11        21170  1.187548

# %% [markdown]
# # Binning
# * Divid persons based on persons

# %%
pd.get_dummies(ship['sex'])

ship[ship["sex"]== 1]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %% [markdown]
# ## Bel Curve
# Normal Distribution

# %%
from scipy.stats import norm
x_axis = np.arange(-4,4,0.1)
plt.plot(x_axis,norm.pdf(x_axis,0,1))
